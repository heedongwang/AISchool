# %% [markdown]
# ![image.png](attachment:d55e981c-061a-4367-8ec7-443d2323b5bb.png)
# ![image.png](attachment:2da69294-66e5-41f6-9aa7-eacc615c5be8.png)

# %%
younghwa={'이름':'최영화','나이':20,'전화번호':'01068054567'}
younghwa
# Out:
# {'이름': '최영화', '나이': 20, '전화번호': '01068054567'}

# %%
#데이터 추출=> 딕셔너리명[key]
younghwa['이름']
# Out:
# '최영화'

# %%
#데이터 추가
younghwa['취미']='수영'
younghwa
# Out:
# {'이름': '최영화', '나이': 20, '전화번호': '01068054567', '취미': '수영'}

# %%
#value값만 확인
younghwa.values()
# Out:
# dict_values(['최영화', 20, '01068054567', '수영'])

# %%
younghwa['취미']=['수영','공부','배드민턴','방탈출','여행']
younghwa['취미']
# Out:
# ['수영', '공부', '배드민턴', '방탈출', '여행']
